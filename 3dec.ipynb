# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle as pkl

# %%
with open('embImgRe_pardec.pkl','rb') as f:
            print
            alldata = pkl.load(f)

# %%
len(alldata)
# Out:
# 27

# %%
alldata[0][1].shape
# Out:
# (256, 256, 128, 3)

# %%
a = np.concatenate((alldata[0][1],alldata[0][2]),axis =2)
a = np.clip(a,0,255.0).astype(np.uint8)

# %%
plt.imshow(a[50])

# %%
plt.imshow(a[26])

# %%
plt.imshow(a[255])

# %%
plt.imshow(a[55])
